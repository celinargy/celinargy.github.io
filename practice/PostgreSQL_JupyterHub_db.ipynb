# %% [markdown]
# # PostgreSQL: how to access from JupyterHub

# %% [markdown]
# [PostgreSQL](https://www.postgresql.org/) is a powerful, open source object-relational database system with over 30 years of active development that has earned it a strong reputation for reliability, feature robustness, and performance.

# %% [markdown]
# ## Import libraries and set access parameters

# %%
import os
import json
import psycopg2
from psycopg2.extras import DictCursor

# %% [markdown]
# Set host to get to database. Our database for JupyterHub usage in our platform is stored in Yandex.Cloud

# %%
POSTGRESQL_HOST = 'rc1b-e8x9spo1qs5m9z6n.mdb.yandexcloud.net'

# %% [markdown]
# [Psycopg](https://www.psycopg.org/docs/index.html) is installed in the JupyterHub environment as a PostgreSQL database adapter for Python. So we are going to use this library for our demo access.

# %% [markdown]
# ## Access option #1 (close connection and cursor manually)

# %% [markdown]
# In order to connect to PostgreSQL database a [cursor](https://www.psycopg.org/docs/cursor.html) should be created with parameters like database's host, username and password.

# %%
conn = psycopg2.connect(
    dbname='dbsimba', 
    user='dbsimbareader',
    password='Reader2020', 
    host=POSTGRESQL_HOST,
    port='6432'
)
cur = conn.cursor()

# %% [markdown]
# Now create SQL query:

# %%
query = 'SELECT * FROM jhublogs LIMIT 5'

# %% [markdown]
# ...and run it:

# %%
cur.execute(query)
records = cur.fetchall()
cur.close()
conn.close()

# %% [markdown]
# Data recieved is now in `records` variable:

# %%
records
# Out:
# [(1,
#   datetime.datetime(2022, 7, 29, 12, 39, 25, 135853),
#   'hub',
#   'cl1flrrk4hvdbm084md4-yjyh',
#   'hub-5bb9b9c56c-2l9k2',
#   'I',
#   datetime.datetime(2022, 7, 29, 12, 39, 25, 135000),
#   'JupyterHub',
#   'proxy',
#   '319',
#   'Checking routes'),
#  (2,
#   datetime.datetime(2022, 7, 29, 12, 39, 39, 54310),
#   'hub',
#   'cl1flrrk4hvdbm084md4-yjyh',
#   'hub-5bb9b9c56c-2l9k2',
#   'I',
#   datetime.datetime(2022, 7, 29, 12, 39, 39, 54000),
#   'JupyterHub',
#   'log',
#   '181',
#   '200 POST /hub/api/users/st039823/activity (st039823@10.112.128.111) 12.02ms'),
#  (3,
#   datetime.datetime(2022, 7, 29, 12, 40, 25, 136866),
#   'hub',
#   'cl1flrrk4hvdbm084md4-yjyh',
#   'hub-5bb9b9c56c-2l9k2',
#   'I',
#   datetime.datetime(2022, 7, 29, 12, 40, 25, 136000),
#   'JupyterHub',
#   'proxy',
#   '319',
#   'Checking routes'),
#  (4,
#   datetime.datetime(2022, 7, 29, 12, 41, 25, 137800),
#   'hub',
#   'cl1flrrk4hvdbm084md4-yjyh',
#   'hub-5bb9b9c56c-2l9k2',
#   'I',
#   datetime.datetime(2022, 7, 29, 12, 41, 25, 137000),
#   'JupyterHub',
#   'proxy',
#   '319',
#   'Checking routes'),
#  (5,
#   datetime.datetime(2022, 7, 29, 12, 41, 25, 259420),
#   'hub',
#   'cl1flrrk4hvdbm084md4-yjyh',
#   'hub-5bb9b9c56c-2l9k2',
#   'I',
#   datetime.datetime(2022, 7, 29, 12, 41, 25, 259000),
#   'JupyterHub',
#   'log',
#   '181',
#   '200 GET /hub/api/users (cull-idle@127.0.0.1) 17.88ms')]

# %% [markdown]
# ## Access option #2 (use 'with' context manager)

# %%
with psycopg2.connect(
    dbname='dbsimba', 
    user='dbsimbareader',
    password='Reader2020', 
    host=POSTGRESQL_HOST,
    port='6432'
) as conn:
    with conn.cursor() as cur:
        cur.execute('SELECT * FROM jhublogs LIMIT 5')
        records = cur.fetchall()

# %%
records
# Out:
# [(1,
#   datetime.datetime(2022, 7, 29, 12, 39, 25, 135853),
#   'hub',
#   'cl1flrrk4hvdbm084md4-yjyh',
#   'hub-5bb9b9c56c-2l9k2',
#   'I',
#   datetime.datetime(2022, 7, 29, 12, 39, 25, 135000),
#   'JupyterHub',
#   'proxy',
#   '319',
#   'Checking routes'),
#  (2,
#   datetime.datetime(2022, 7, 29, 12, 39, 39, 54310),
#   'hub',
#   'cl1flrrk4hvdbm084md4-yjyh',
#   'hub-5bb9b9c56c-2l9k2',
#   'I',
#   datetime.datetime(2022, 7, 29, 12, 39, 39, 54000),
#   'JupyterHub',
#   'log',
#   '181',
#   '200 POST /hub/api/users/st039823/activity (st039823@10.112.128.111) 12.02ms'),
#  (3,
#   datetime.datetime(2022, 7, 29, 12, 40, 25, 136866),
#   'hub',
#   'cl1flrrk4hvdbm084md4-yjyh',
#   'hub-5bb9b9c56c-2l9k2',
#   'I',
#   datetime.datetime(2022, 7, 29, 12, 40, 25, 136000),
#   'JupyterHub',
#   'proxy',
#   '319',
#   'Checking routes'),
#  (4,
#   datetime.datetime(2022, 7, 29, 12, 41, 25, 137800),
#   'hub',
#   'cl1flrrk4hvdbm084md4-yjyh',
#   'hub-5bb9b9c56c-2l9k2',
#   'I',
#   datetime.datetime(2022, 7, 29, 12, 41, 25, 137000),
#   'JupyterHub',
#   'proxy',
#   '319',
#   'Checking routes'),
#  (5,
#   datetime.datetime(2022, 7, 29, 12, 41, 25, 259420),
#   'hub',
#   'cl1flrrk4hvdbm084md4-yjyh',
#   'hub-5bb9b9c56c-2l9k2',
#   'I',
#   datetime.datetime(2022, 7, 29, 12, 41, 25, 259000),
#   'JupyterHub',
#   'log',
#   '181',
#   '200 GET /hub/api/users (cull-idle@127.0.0.1) 17.88ms')]

# %% [markdown]
# ## Multiply queries

# %% [markdown]
# A list of SQL queries in one connection:

# %%
queries = {
    '___DATABASES___': 'SELECT * FROM pg_database',
    '___TABLES___': "SELECT relname FROM pg_class WHERE relkind='r' AND relname !~ '^(pg_|sql_)';",
    '\n___COLUMNS___': "SELECT column_name FROM INFORMATION_SCHEMA.COLUMNS WHERE TABLE_NAME = 'jhublogs';"
}

# %%
with psycopg2.connect(
    dbname='dbsimba', 
    user='dbsimbareader',
    password='Reader2020', 
    host=POSTGRESQL_HOST,
    port='6432'
) as conn:
    for name, query in queries.items():
        print('\n', name)
        with conn.cursor() as cur:
            cur.execute(query)
            for row in cur.fetchall():
                print(row)
# Out:
#  ___DATABASES___
# (14708, 'postgres', 10, 6, 'C', 'C', False, True, -1, 14707, '727', '1', 1663, None)
# (1, 'template1', 10, 6, 'C', 'C', True, True, -1, 14707, '727', '1', 1663, '{=c/postgres,postgres=CTc/postgres}')
# (14707, 'template0', 10, 6, 'C', 'C', True, False, -1, 14707, '727', '1', 1663, '{=c/postgres,postgres=CTc/postgres}')
# (16580, 'dbsimba', 16575, 6, 'C', 'C', False, True, -1, 14707, '727', '1', 1663, '{=T/dbsimbaloader,dbsimbaloader=CTc/dbsimbaloader,admin=c/dbsimbaloader,monitor=c/dbsimbaloader,postgres=c/dbsimbaloader,dbsimbareader=c/dbsimbaloader}')
# (16578, 'dbzoom', 16577, 6, 'C', 'C', False, True, -1, 14707, '727', '1', 1663, '{=T/dbzoomloader,dbzoomloader=CTc/dbzoomloader,admin=c/dbzoomloader,monitor=c/dbzoomloader,postgres=c/dbzoomloader,dbzoomreader=c/dbzoomloader}')
# (16573, 'dbvk', 16414, 6, 'C', 'C', False, True, -1, 14707, '727', '1', 1663, '{=T/dbvkloader,dbvkloader=CTc/dbvkloader,admin=c/dbvkloader,monitor=c/dbvkloader,postgres=c/dbvkloader,dbvkreader=c/dbvkloader}')
# (16582, 'dbsmonk', 16576, 6, 'C', 'C', False, True, -1, 14707, '727', '1', 1663, '{=T/dbsmonkloader,dbsmonkloader=CTc/dbsmonkloader,admin=c/dbsmonkloader,monitor=c/dbsmonkloader,postgres=c/dbsmonkloader,dbsmonkreader=c/dbsmonkloader}')
# (22436, 'dbanket', 22435, 6, 'C', 'C', False, True, -1, 14707, '727', '1', 1663, '{=T/dbanketloader,dbanketloader=CTc/dbanketloader,admin=c/dbanketloader,monitor=c/dbanketloader,postgres=c/dbanketloader,dbanketreader=c/dbanketloader}')
#
#  ___TABLES___
# ('jhublogs',)
#
#
# ___COLUMNS___
# ('log_timestamp',)
# ('time_stamp',)
# ('id',)
# ('kuber_pod_name',)
# ('log_head',)
# ('log_service',)
# ('log_type',)
# ('log_code',)
# ('log_msg',)
# ('kuber_container_name',)
# ('kuber_host',)

# %% [markdown]
# ## SQL for IPython

# %% [markdown]
# The [IPython SQL](https://github.com/catherinedevlin/ipython-sql) framework allows to use [magic commands](https://ipython.readthedocs.io/en/stable/interactive/magics.html) like `%sql` (or `%%sql`) for SQL queries. We can connect to a database, then issue SQL commands within Jupyter.
#
# Let's install library first:

# %%
# !pip install ipython-sql
# Out:
# Requirement already satisfied: ipython-sql in /opt/conda/lib/python3.8/site-packages (0.4.1)
# Requirement already satisfied: sqlalchemy>=0.6.7 in /opt/conda/lib/python3.8/site-packages (from ipython-sql) (1.3.22)
# Requirement already satisfied: ipython>=1.0 in /opt/conda/lib/python3.8/site-packages (from ipython-sql) (7.19.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.8/site-packages (from ipython-sql) (1.15.0)
# Requirement already satisfied: sqlparse in /opt/conda/lib/python3.8/site-packages (from ipython-sql) (0.4.3)
# Requirement already satisfied: ipython-genutils>=0.1.0 in /opt/conda/lib/python3.8/site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: prettytable<1 in /opt/conda/lib/python3.8/site-packages (from ipython-sql) (0.7.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /opt/conda/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (3.0.10)
# Requirement already satisfied: pickleshare in /opt/conda/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (0.7.5)
# Requirement already satisfied: jedi>=0.10 in /opt/conda/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (0.17.2)
# Requirement already satisfied: pygments in /opt/conda/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (2.7.4)
# Requirement already satisfied: setuptools>=18.5 in /opt/conda/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (49.6.0.post20210108)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (4.8.0)
# Requirement already satisfied: backcall in /opt/conda/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (0.2.0)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (4.4.2)
# Requirement already satisfied: traitlets>=4.2 in /opt/conda/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (5.0.5)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /opt/conda/lib/python3.8/site-packages (from jedi>=0.10->ipython>=1.0->ipython-sql) (0.7.1)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.8/site-packages (from pexpect>4.3->ipython>=1.0->ipython-sql) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=1.0->ipython-sql) (0.2.5)

# %% [markdown]
# Enable `sql` in Jupyter notebook cells:

# %%
# %load_ext sql

# %% [markdown]
# Connection data string to be used later:

# %%
user='dbsimbareader'
password='Reader2020'
host=POSTGRESQL_HOST
port='6432'
dbname='dbsimba'

CONNECT_DATA = 'postgresql://{}:{}@{}:{}/{}'.format(
    user,
    password,
    POSTGRESQL_HOST,
    port,
    dbname
)

# %% [markdown]
# Let's look at all databases in PostgreSQL. SQL query can be done after the connection with `%%sql` magic command:

# %%
# %%sql $CONNECT_DATA
#     SELECT * FROM pg_database
# Out:
# 8 rows affected.
# [(14708, 'postgres', 10, 6, 'C', 'C', False, True, -1, 14707, '727', '1', 1663, None),
#  (1, 'template1', 10, 6, 'C', 'C', True, True, -1, 14707, '727', '1', 1663, '{=c/postgres,postgres=CTc/postgres}'),
#  (14707, 'template0', 10, 6, 'C', 'C', True, False, -1, 14707, '727', '1', 1663, '{=c/postgres,postgres=CTc/postgres}'),
#  (16580, 'dbsimba', 16575, 6, 'C', 'C', False, True, -1, 14707, '727', '1', 1663, '{=T/dbsimbaloader,dbsimbaloader=CTc/dbsimbaloader,admin=c/dbsimbaloader,monitor=c/dbsimbaloader,postgres=c/dbsimbaloader,dbsimbareader=c/dbsimbaloader}'),
#  (16578, 'dbzoom', 16577, 6, 'C', 'C', False, True, -1, 14707, '727', '1', 1663, '{=T/dbzoomloader,dbzoomloader=CTc/dbzoomloader,admin=c/dbzoomloader,monitor=c/dbzoomloader,postgres=c/dbzoomloader,dbzoomreader=c/dbzoomloader}'),
#  (16573, 'dbvk', 16414, 6, 'C', 'C', False, True, -1, 14707, '727', '1', 1663, '{=T/dbvkloader,dbvkloader=CTc/dbvkloader,admin=c/dbvkloader,monitor=c/dbvkloader,postgres=c/dbvkloader,dbvkreader=c/dbvkloader}'),
#  (16582, 'dbsmonk', 16576, 6, 'C', 'C', False, True, -1, 14707, '727', '1', 1663, '{=T/dbsmonkloader,dbsmonkloader=CTc/dbsmonkloader,admin=c/dbsmonkloader,monitor=c/dbsmonkloader,postgres=c/dbsmonkloader,dbsmonkreader=c/dbsmonkloader}'),
#  (22436, 'dbanket', 22435, 6, 'C', 'C', False, True, -1, 14707, '727', '1', 1663, '{=T/dbanketloader,dbanketloader=CTc/dbanketloader,admin=c/dbanketloader,monitor=c/dbanketloader,postgres=c/dbanketloader,dbanketreader=c/dbanketloader}')]

# %% [markdown]
# Connect string can be omitted (just use `%sql` NOT the `%%sql`) if connection is done earlier. Now will get all tables in `demo` database:

# %%
# %sql SELECT tablename AS table FROM pg_tables WHERE tablename !~ '^(pg_|sql_)'
# Out:
#  * postgresql://dbsimbareader:***@rc1b-e8x9spo1qs5m9z6n.mdb.yandexcloud.net:6432/dbsimba
# 1 rows affected.
# [('jhublogs',)]

# %%
# %sql SELECT * FROM jhublogs LIMIT 5
# Out:
#  * postgresql://dbsimbareader:***@rc1b-e8x9spo1qs5m9z6n.mdb.yandexcloud.net:6432/dbsimba
# 5 rows affected.
# [(1, datetime.datetime(2022, 7, 29, 12, 39, 25, 135853), 'hub', 'cl1flrrk4hvdbm084md4-yjyh', 'hub-5bb9b9c56c-2l9k2', 'I', datetime.datetime(2022, 7, 29, 12, 39, 25, 135000), 'JupyterHub', 'proxy', '319', 'Checking routes'),
#  (2, datetime.datetime(2022, 7, 29, 12, 39, 39, 54310), 'hub', 'cl1flrrk4hvdbm084md4-yjyh', 'hub-5bb9b9c56c-2l9k2', 'I', datetime.datetime(2022, 7, 29, 12, 39, 39, 54000), 'JupyterHub', 'log', '181', '200 POST /hub/api/users/st039823/activity (st039823@10.112.128.111) 12.02ms'),
#  (3, datetime.datetime(2022, 7, 29, 12, 40, 25, 136866), 'hub', 'cl1flrrk4hvdbm084md4-yjyh', 'hub-5bb9b9c56c-2l9k2', 'I', datetime.datetime(2022, 7, 29, 12, 40, 25, 136000), 'JupyterHub', 'proxy', '319', 'Checking routes'),
#  (4, datetime.datetime(2022, 7, 29, 12, 41, 25, 137800), 'hub', 'cl1flrrk4hvdbm084md4-yjyh', 'hub-5bb9b9c56c-2l9k2', 'I', datetime.datetime(2022, 7, 29, 12, 41, 25, 137000), 'JupyterHub', 'proxy', '319', 'Checking routes'),
#  (5, datetime.datetime(2022, 7, 29, 12, 41, 25, 259420), 'hub', 'cl1flrrk4hvdbm084md4-yjyh', 'hub-5bb9b9c56c-2l9k2', 'I', datetime.datetime(2022, 7, 29, 12, 41, 25, 259000), 'JupyterHub', 'log', '181', '200 GET /hub/api/users (cull-idle@127.0.0.1) 17.88ms')]

# %%
# we can see some activity loggin for different users
# %sql SELECT * FROM jhublogs WHERE log_msg LIKE '%gorovoy%' ORDER by time_stamp DESC LIMIT 100
# Out:
#  * postgresql://dbsimbareader:***@rc1b-e8x9spo1qs5m9z6n.mdb.yandexcloud.net:6432/dbsimba
# 100 rows affected.
# [(208365, datetime.datetime(2022, 9, 28, 10, 19, 30, 307149), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 28, 10, 19, 30, 306000), 'JupyterHub', 'log', '181', '200 GET /hub/spawn (vladimirgorovoy@10.112.129.65) 5.05ms'),
#  (208364, datetime.datetime(2022, 9, 28, 10, 19, 30, 239423), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 28, 10, 19, 30, 239000), 'JupyterHub', 'log', '181', '302 GET /hub/ -> /hub/spawn (vladimirgorovoy@10.112.129.65) 17.94ms'),
#  (208363, datetime.datetime(2022, 9, 28, 10, 19, 30, 237196), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'E', datetime.datetime(2022, 9, 28, 10, 19, 30, 236000), 'JupyterHub', 'log', '181', '503 GET /hub/user/vladimirgorovoy/tree/__DATA/BABD_Fall_2022 (vladimirgorovoy@10.112.129.65) 16.10ms'),
#  (208361, datetime.datetime(2022, 9, 28, 10, 19, 30, 150292), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 28, 10, 19, 30, 150000), 'JupyterHub', 'log', '181', '302 GET /user/vladimirgorovoy/tree/__DATA/BABD_Fall_2022 -> /hub/user/vladimirgorovoy/tree/__DATA/BABD_Fall_2022 (@10.112.129.65) 1.11ms'),
#  (196328, datetime.datetime(2022, 9, 24, 15, 37, 34, 566586), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 24, 15, 37, 34, 566000), 'JupyterHub', 'log', '181', '302 GET /hub/user/vladimirgorovoy/notebooks/__DATA/BABD_Fall_2022/labs/Lab2_ClickHouse_GSOM_logs_with_hints.ipynb -> /user/st056606/notebooks/__DATA/BABD_Fall_2022/labs/Lab2_ClickHouse_GSOM_logs_with_hints.ipynb (st056606@10.112.129.65) 9.43ms'),
#  (196327, datetime.datetime(2022, 9, 24, 15, 37, 34, 565929), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'W', datetime.datetime(2022, 9, 24, 15, 37, 34, 565000), 'JupyterHub', 'base', '1437', "User st056606 requested server for vladimirgorovoy, which they don't own"),
#  (196326, datetime.datetime(2022, 9, 24, 15, 37, 34, 487842), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 24, 15, 37, 34, 487000), 'JupyterHub', 'log', '181', '302 GET /user/vladimirgorovoy/notebooks/__DATA/BABD_Fall_2022/labs/Lab2_ClickHouse_GSOM_logs_with_hints.ipynb -> /hub/user/vladimirgorovoy/notebooks/__DATA/BABD_Fall_2022/labs/Lab2_ClickHouse_GSOM_logs_with_hints.ipynb (@10.112.129.65) 0.94ms'),
#  (196509, datetime.datetime(2022, 9, 24, 15, 26, 37, 152956), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 24, 15, 26, 37, 152000), 'JupyterHub', 'log', '181', '302 GET /hub/user/vladimirgorovoy/notebooks/__DATA/BABD_Fall_2022/labs/Lab2_ClickHouse_GSOM_logs_with_hints.ipynb -> /user/st056606/notebooks/__DATA/BABD_Fall_2022/labs/Lab2_ClickHouse_GSOM_logs_with_hints.ipynb (st056606@10.112.129.65) 20.18ms'),
#  (196508, datetime.datetime(2022, 9, 24, 15, 26, 37, 152246), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'W', datetime.datetime(2022, 9, 24, 15, 26, 37, 151000), 'JupyterHub', 'base', '1437', "User st056606 requested server for vladimirgorovoy, which they don't own"),
#  (196507, datetime.datetime(2022, 9, 24, 15, 26, 37, 59979), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 24, 15, 26, 37, 59000), 'JupyterHub', 'log', '181', '302 GET /user/vladimirgorovoy/notebooks/__DATA/BABD_Fall_2022/labs/Lab2_ClickHouse_GSOM_logs_with_hints.ipynb -> /hub/user/vladimirgorovoy/notebooks/__DATA/BABD_Fall_2022/labs/Lab2_ClickHouse_GSOM_logs_with_hints.ipynb (@10.112.129.65) 0.93ms'),
#  (196300, datetime.datetime(2022, 9, 24, 14, 51, 26, 803427), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 24, 14, 51, 26, 803000), 'JupyterHub', 'log', '181', '200 GET /hub/spawn (vladimirgorovoy@10.112.129.65) 5.66ms'),
#  (196299, datetime.datetime(2022, 9, 24, 14, 51, 26, 739246), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 24, 14, 51, 26, 739000), 'JupyterHub', 'log', '181', '302 GET /hub/ -> /hub/spawn (vladimirgorovoy@10.112.129.65) 10.97ms'),
#  (193880, datetime.datetime(2022, 9, 23, 15, 16, 8, 817321), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 15, 16, 8, 817000), 'JupyterHub', 'log', '181', '204 DELETE /hub/api/users/vladimirgorovoy/server (cull-idle@127.0.0.1) 8289.92ms'),
#  (193879, datetime.datetime(2022, 9, 23, 15, 16, 8, 816963), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 15, 16, 8, 816000), 'JupyterHub', 'base', '1110', 'User vladimirgorovoy server took 8.286 seconds to stop'),
#  (193878, datetime.datetime(2022, 9, 23, 15, 16, 0, 531978), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 15, 16, 0, 531000), 'JupyterHub', 'spawner', '1997', 'Deleting pod jupyter-vladimirgorovoy'),
#  (193877, datetime.datetime(2022, 9, 23, 15, 16, 0, 530477), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 15, 16, 0, 530000), 'JupyterHub', 'proxy', '281', 'Removing user vladimirgorovoy from proxy (/user/vladimirgorovoy/)'),
#  (193876, datetime.datetime(2022, 9, 23, 15, 16, 0, 524243), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', '', None, '', '', '', '[I 220923 15:16:00 __init__:191] Culling server vladimirgorovoy (inactive for 01:00:05)\n'),
#  (193873, datetime.datetime(2022, 9, 23, 15, 15, 37, 923322), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 15, 15, 37, 923000), 'JupyterHub', 'log', '181', '200 POST /hub/api/users/vladimirgorovoy/activity (vladimirgorovoy@10.112.129.80) 11.53ms'),
#  (193739, datetime.datetime(2022, 9, 23, 15, 10, 54, 388038), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 15, 10, 54, 387000), 'JupyterHub', 'log', '181', '200 POST /hub/api/users/vladimirgorovoy/activity (vladimirgorovoy@10.112.129.80) 11.44ms'),
#  (193802, datetime.datetime(2022, 9, 23, 15, 6, 10, 822629), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 15, 6, 10, 822000), 'JupyterHub', 'log', '181', '200 POST /hub/api/users/vladimirgorovoy/activity (vladimirgorovoy@10.112.129.80) 11.47ms'),
#  (193678, datetime.datetime(2022, 9, 23, 15, 0, 52, 977457), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 15, 0, 52, 977000), 'JupyterHub', 'log', '181', '200 POST /hub/api/users/vladimirgorovoy/activity (vladimirgorovoy@10.112.129.80) 12.19ms'),
#  (193673, datetime.datetime(2022, 9, 23, 14, 56, 22, 947565), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 14, 56, 22, 947000), 'JupyterHub', 'log', '181', '200 POST /hub/api/users/vladimirgorovoy/activity (vladimirgorovoy@10.112.129.80) 14.06ms'),
#  (193658, datetime.datetime(2022, 9, 23, 14, 51, 31, 20706), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 14, 51, 31, 20000), 'JupyterHub', 'log', '181', '200 POST /hub/api/users/vladimirgorovoy/activity (vladimirgorovoy@10.112.129.80) 23.57ms'),
#  (193648, datetime.datetime(2022, 9, 23, 14, 46, 24, 236885), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 14, 46, 24, 236000), 'JupyterHub', 'log', '181', '200 POST /hub/api/users/vladimirgorovoy/activity (vladimirgorovoy@10.112.129.80) 12.26ms'),
#  (193599, datetime.datetime(2022, 9, 23, 14, 41, 19, 78435), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 14, 41, 19, 78000), 'JupyterHub', 'log', '181', '200 POST /hub/api/users/vladimirgorovoy/activity (vladimirgorovoy@10.112.129.80) 12.07ms'),
#  (193689, datetime.datetime(2022, 9, 23, 14, 35, 57, 678422), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 14, 35, 57, 678000), 'JupyterHub', 'log', '181', '200 POST /hub/api/users/vladimirgorovoy/activity (vladimirgorovoy@10.112.129.80) 11.77ms'),
#  (193589, datetime.datetime(2022, 9, 23, 14, 30, 45, 595964), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 14, 30, 45, 595000), 'JupyterHub', 'log', '181', '200 POST /hub/api/users/vladimirgorovoy/activity (vladimirgorovoy@10.112.129.80) 11.77ms'),
#  (193630, datetime.datetime(2022, 9, 23, 14, 25, 36, 706197), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 14, 25, 36, 705000), 'JupyterHub', 'log', '181', '200 POST /hub/api/users/vladimirgorovoy/activity (vladimirgorovoy@10.112.129.80) 12.28ms'),
#  (193621, datetime.datetime(2022, 9, 23, 14, 20, 18, 857304), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 14, 20, 18, 857000), 'JupyterHub', 'log', '181', '200 POST /hub/api/users/vladimirgorovoy/activity (vladimirgorovoy@10.112.129.80) 12.42ms'),
#  (193712, datetime.datetime(2022, 9, 23, 14, 15, 52, 871662), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'W', datetime.datetime(2022, 9, 23, 14, 15, 52, 871000), 'JupyterHub', 'log', '181', '404 GET /hub/api/authorizations/token/[secret] (vladimirgorovoy@10.112.129.80) 13.21ms'),
#  (193710, datetime.datetime(2022, 9, 23, 14, 15, 20, 579184), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 14, 15, 20, 578000), 'JupyterHub', 'log', '181', '200 POST /hub/api/users/vladimirgorovoy/activity (vladimirgorovoy@10.112.129.80) 12.54ms'),
#  (193700, datetime.datetime(2022, 9, 23, 14, 9, 57, 22993), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 14, 9, 57, 22000), 'JupyterHub', 'log', '181', '200 POST /hub/api/users/vladimirgorovoy/activity (vladimirgorovoy@10.112.129.80) 13.35ms'),
#  (193614, datetime.datetime(2022, 9, 23, 14, 5, 17, 685089), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 14, 5, 17, 684000), 'JupyterHub', 'log', '181', '200 POST /hub/api/users/vladimirgorovoy/activity (vladimirgorovoy@10.112.129.80) 10.66ms'),
#  (193605, datetime.datetime(2022, 9, 23, 14, 0, 37, 656226), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'W', datetime.datetime(2022, 9, 23, 14, 0, 37, 655000), 'JupyterHub', 'log', '181', '404 GET /hub/api/authorizations/token/[secret] (vladimirgorovoy@10.112.129.80) 5.71ms'),
#  (193493, datetime.datetime(2022, 9, 23, 14, 0, 21, 828744), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 14, 0, 21, 828000), 'JupyterHub', 'log', '181', '200 POST /hub/api/users/vladimirgorovoy/activity (vladimirgorovoy@10.112.129.80) 11.54ms'),
#  (193478, datetime.datetime(2022, 9, 23, 13, 55, 31, 560071), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 13, 55, 31, 559000), 'JupyterHub', 'log', '181', '200 POST /hub/api/users/vladimirgorovoy/activity (vladimirgorovoy@10.112.129.80) 4.02ms'),
#  (193477, datetime.datetime(2022, 9, 23, 13, 55, 18, 635468), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'W', datetime.datetime(2022, 9, 23, 13, 55, 18, 635000), 'JupyterHub', 'log', '181', '404 GET /hub/api/authorizations/token/[secret] (vladimirgorovoy@10.112.129.80) 12.83ms'),
#  (193458, datetime.datetime(2022, 9, 23, 13, 50, 21, 54171), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 13, 50, 21, 53000), 'JupyterHub', 'log', '181', '200 POST /hub/api/users/vladimirgorovoy/activity (vladimirgorovoy@10.112.129.80) 12.33ms'),
#  (193535, datetime.datetime(2022, 9, 23, 13, 48, 34, 869469), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'W', datetime.datetime(2022, 9, 23, 13, 48, 34, 869000), 'JupyterHub', 'log', '181', '404 GET /hub/api/authorizations/token/[secret] (vladimirgorovoy@10.112.129.80) 12.33ms'),
#  (193528, datetime.datetime(2022, 9, 23, 13, 45, 22, 766287), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 13, 45, 22, 766000), 'JupyterHub', 'log', '181', '200 POST /hub/api/users/vladimirgorovoy/activity (vladimirgorovoy@10.112.129.80) 16.18ms'),
#  (193518, datetime.datetime(2022, 9, 23, 13, 40, 38, 869704), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 13, 40, 38, 869000), 'JupyterHub', 'log', '181', '200 POST /hub/api/users/vladimirgorovoy/activity (vladimirgorovoy@10.112.129.80) 10.69ms'),
#  (193579, datetime.datetime(2022, 9, 23, 13, 35, 34, 418272), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 13, 35, 34, 417000), 'JupyterHub', 'log', '181', '200 POST /hub/api/users/vladimirgorovoy/activity (vladimirgorovoy@10.112.129.80) 11.42ms'),
#  (193501, datetime.datetime(2022, 9, 23, 13, 30, 41, 72313), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 13, 30, 41, 72000), 'JupyterHub', 'log', '181', '200 POST /hub/api/users/vladimirgorovoy/activity (vladimirgorovoy@10.112.129.80) 12.08ms'),
#  (193445, datetime.datetime(2022, 9, 23, 13, 25, 51, 935728), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 13, 25, 51, 935000), 'JupyterHub', 'log', '181', '200 POST /hub/api/users/vladimirgorovoy/activity (vladimirgorovoy@10.112.129.80) 11.58ms'),
#  (193548, datetime.datetime(2022, 9, 23, 13, 20, 28, 892560), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 13, 20, 28, 892000), 'JupyterHub', 'log', '181', '200 POST /hub/api/users/vladimirgorovoy/activity (vladimirgorovoy@10.112.129.80) 10.84ms'),
#  (193538, datetime.datetime(2022, 9, 23, 13, 15, 53, 249102), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 13, 15, 53, 248000), 'JupyterHub', 'log', '181', '200 POST /hub/api/users/vladimirgorovoy/activity (vladimirgorovoy@10.112.129.80) 11.91ms'),
#  (193567, datetime.datetime(2022, 9, 23, 13, 11, 11, 611555), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 13, 11, 11, 611000), 'JupyterHub', 'log', '181', '200 POST /hub/api/users/vladimirgorovoy/activity (vladimirgorovoy@10.112.129.80) 11.53ms'),
#  (193553, datetime.datetime(2022, 9, 23, 13, 5, 50, 421779), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 13, 5, 50, 421000), 'JupyterHub', 'log', '181', '200 POST /hub/api/users/vladimirgorovoy/activity (vladimirgorovoy@10.112.129.80) 11.07ms'),
#  (193302, datetime.datetime(2022, 9, 23, 13, 0, 25, 627746), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 13, 0, 25, 627000), 'JupyterHub', 'log', '181', '200 POST /hub/api/users/vladimirgorovoy/activity (vladimirgorovoy@10.112.129.80) 11.45ms'),
#  (193252, datetime.datetime(2022, 9, 23, 12, 55, 4, 396656), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 12, 55, 4, 396000), 'JupyterHub', 'log', '181', '200 POST /hub/api/users/vladimirgorovoy/activity (vladimirgorovoy@10.112.129.80) 11.19ms'),
#  (193281, datetime.datetime(2022, 9, 23, 12, 49, 37, 469365), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 12, 49, 37, 468000), 'JupyterHub', 'log', '181', '200 POST /hub/api/users/vladimirgorovoy/activity (vladimirgorovoy@10.112.129.80) 11.14ms'),
#  (193339, datetime.datetime(2022, 9, 23, 12, 44, 15, 389946), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 12, 44, 15, 389000), 'JupyterHub', 'log', '181', '200 POST /hub/api/users/vladimirgorovoy/activity (vladimirgorovoy@10.112.129.80) 17.86ms'),
#  (193419, datetime.datetime(2022, 9, 23, 12, 39, 7, 966614), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 12, 39, 7, 966000), 'JupyterHub', 'log', '181', '200 POST /hub/api/users/vladimirgorovoy/activity (vladimirgorovoy@10.112.129.80) 13.35ms'),
#  (193320, datetime.datetime(2022, 9, 23, 12, 34, 24, 826997), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 12, 34, 24, 826000), 'JupyterHub', 'log', '181', '200 POST /hub/api/users/vladimirgorovoy/activity (vladimirgorovoy@10.112.129.80) 14.64ms'),
#  (193333, datetime.datetime(2022, 9, 23, 12, 29, 6, 548133), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 12, 29, 6, 547000), 'JupyterHub', 'log', '181', '200 POST /hub/api/users/vladimirgorovoy/activity (vladimirgorovoy@10.112.129.80) 11.08ms'),
#  (193400, datetime.datetime(2022, 9, 23, 12, 24, 1, 341410), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 12, 24, 1, 341000), 'JupyterHub', 'log', '181', '200 GET /hub/login?next=%2Fhub%2Fapi%2Foauth2%2Fauthorize%3Fclient_id%3Djupyterhub-user-vladimirgorovoy%26redirect_uri%3D%252Fuser%252Fvladimirgorovo ... (141 characters truncated) ... sYWRpbWlyZ29yb3ZveS9ub3RlYm9va3MvX19EQVRBL0JBQkRfRmFsbF8yMDIyL2xhYnMvTGFiMl9DbGlja0hvdXNlX0dTT01fbG9nc193aXRoX2hpbnRzLmlweW5iIn0 (@10.129.0.5) 1.33ms'),
#  (193399, datetime.datetime(2022, 9, 23, 12, 24, 1, 51868), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 12, 24, 1, 51000), 'JupyterHub', 'log', '181', '302 GET /hub/api/oauth2/authorize?client_id=jupyterhub-user-vladimirgorovoy&redirect_uri=%2Fuser%2Fvladimirgorovoy%2Foauth_callback&response_type=cod ... (305 characters truncated) ... RpbWlyZ29yb3ZveS9ub3RlYm9va3MvX19EQVRBL0JBQkRfRmFsbF8yMDIyL2xhYnMvTGFiMl9DbGlja0hvdXNlX0dTT01fbG9nc193aXRoX2hpbnRzLmlweW5iIn0 (@10.112.129.65) 0.85ms'),
#  (193397, datetime.datetime(2022, 9, 23, 12, 23, 55, 616533), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 12, 23, 55, 616000), 'JupyterHub', 'log', '181', '200 POST /hub/api/users/vladimirgorovoy/activity (vladimirgorovoy@10.112.129.80) 17.90ms'),
#  (193375, datetime.datetime(2022, 9, 23, 12, 21, 54, 481923), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 12, 21, 54, 481000), 'JupyterHub', 'log', '181', '200 GET /hub/api/authorizations/token/[secret] (vladimirgorovoy@10.112.129.80) 25.73ms'),
#  (193437, datetime.datetime(2022, 9, 23, 12, 18, 27, 918008), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 12, 18, 27, 917000), 'JupyterHub', 'log', '181', '200 POST /hub/api/users/vladimirgorovoy/activity (vladimirgorovoy@10.112.129.80) 24.14ms'),
#  (193432, datetime.datetime(2022, 9, 23, 12, 16, 11, 49889), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 12, 16, 11, 49000), 'JupyterHub', 'log', '181', '200 GET /hub/api/authorizations/token/[secret] (vladimirgorovoy@10.112.129.80) 18.75ms'),
#  (193425, datetime.datetime(2022, 9, 23, 12, 13, 10, 300889), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 12, 13, 10, 300000), 'JupyterHub', 'log', '181', '200 POST /hub/api/users/vladimirgorovoy/activity (vladimirgorovoy@10.112.129.80) 11.93ms'),
#  (193267, datetime.datetime(2022, 9, 23, 12, 10, 11, 94177), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 12, 10, 11, 93000), 'JupyterHub', 'log', '181', '200 GET /hub/api/authorizations/token/[secret] (vladimirgorovoy@10.112.129.80) 42.11ms'),
#  (193263, datetime.datetime(2022, 9, 23, 12, 8, 8, 659276), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 12, 8, 8, 658000), 'JupyterHub', 'log', '181', '200 POST /hub/api/users/vladimirgorovoy/activity (vladimirgorovoy@10.112.129.80) 12.95ms'),
#  (193291, datetime.datetime(2022, 9, 23, 12, 3, 35, 714510), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 12, 3, 35, 714000), 'JupyterHub', 'log', '181', '200 POST /hub/api/users/vladimirgorovoy/activity (vladimirgorovoy@10.112.129.80) 10.43ms'),
#  (193290, datetime.datetime(2022, 9, 23, 12, 3, 31, 789913), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 12, 3, 31, 789000), 'JupyterHub', 'log', '181', '200 GET /hub/api/authorizations/token/[secret] (vladimirgorovoy@10.112.129.80) 31.18ms'),
#  (193197, datetime.datetime(2022, 9, 23, 11, 58, 20, 713487), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 11, 58, 20, 713000), 'JupyterHub', 'log', '181', '200 POST /hub/api/users/vladimirgorovoy/activity (vladimirgorovoy@10.112.129.80) 11.56ms'),
#  (193195, datetime.datetime(2022, 9, 23, 11, 58, 11, 44516), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 11, 58, 11, 44000), 'JupyterHub', 'log', '181', '200 GET /hub/api/authorizations/token/[secret] (vladimirgorovoy@10.112.129.80) 18.10ms'),
#  (193147, datetime.datetime(2022, 9, 23, 11, 52, 53, 794596), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 11, 52, 53, 794000), 'JupyterHub', 'log', '181', '200 POST /hub/api/users/vladimirgorovoy/activity (vladimirgorovoy@10.112.129.80) 18.29ms'),
#  (193142, datetime.datetime(2022, 9, 23, 11, 51, 28, 290242), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 11, 51, 28, 289000), 'JupyterHub', 'log', '181', '200 GET /hub/api/authorizations/token/[secret] (vladimirgorovoy@10.112.129.80) 17.22ms'),
#  (193225, datetime.datetime(2022, 9, 23, 11, 47, 56, 456831), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 11, 47, 56, 456000), 'JupyterHub', 'log', '181', '200 POST /hub/api/users/vladimirgorovoy/activity (vladimirgorovoy@10.112.129.80) 11.54ms'),
#  (193217, datetime.datetime(2022, 9, 23, 11, 45, 43, 276416), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 11, 45, 43, 276000), 'JupyterHub', 'log', '181', '200 GET /hub/api/authorizations/token/[secret] (vladimirgorovoy@10.112.129.80) 17.88ms'),
#  (193182, datetime.datetime(2022, 9, 23, 11, 43, 19, 331263), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 11, 43, 19, 330000), 'JupyterHub', 'log', '181', '200 POST /hub/api/users/vladimirgorovoy/activity (vladimirgorovoy@10.112.129.80) 16.31ms'),
#  (193156, datetime.datetime(2022, 9, 23, 11, 40, 11, 32987), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 11, 40, 11, 32000), 'JupyterHub', 'log', '181', '200 GET /hub/api/authorizations/token/[secret] (vladimirgorovoy@10.112.129.80) 19.23ms'),
#  (193130, datetime.datetime(2022, 9, 23, 11, 38, 43, 883152), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 11, 38, 43, 882000), 'JupyterHub', 'log', '181', '200 POST /hub/api/users/vladimirgorovoy/activity (vladimirgorovoy@10.112.129.80) 18.65ms'),
#  (193124, datetime.datetime(2022, 9, 23, 11, 33, 29, 603743), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 11, 33, 29, 603000), 'JupyterHub', 'log', '181', '200 GET /hub/api/authorizations/token/[secret] (vladimirgorovoy@10.112.129.80) 12.37ms'),
#  (193123, datetime.datetime(2022, 9, 23, 11, 33, 29, 587996), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 11, 33, 29, 587000), 'JupyterHub', 'log', '181', '200 POST /hub/api/oauth2/token (vladimirgorovoy@10.112.129.80) 23.05ms'),
#  (193122, datetime.datetime(2022, 9, 23, 11, 33, 29, 496974), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 11, 33, 29, 496000), 'JupyterHub', 'log', '181', '302 GET /hub/api/oauth2/authorize?client_id=jupyterhub-user-vladimirgorovoy&redirect_uri=%2Fuser%2Fvladimirgorovoy%2Foauth_callback&response_type=code&state=[secret] -> /user/vladimirgorovoy/oauth_callback?code=[secret]&state=[secret] (vladimirgorovoy@10.129.0.5) 11.79ms'),
#  (193121, datetime.datetime(2022, 9, 23, 11, 33, 29, 310215), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 11, 33, 29, 309000), 'JupyterHub', 'log', '181', '302 GET /hub/spawn-pending/vladimirgorovoy -> /user/vladimirgorovoy/ (vladimirgorovoy@10.129.0.5) 2.78ms'),
#  (193120, datetime.datetime(2022, 9, 23, 11, 33, 29, 241388), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 11, 33, 29, 241000), 'JupyterHub', 'log', '181', '200 GET /hub/api/users/vladimirgorovoy/server/progress (vladimirgorovoy@10.129.0.5) 23561.44ms'),
#  (193119, datetime.datetime(2022, 9, 23, 11, 33, 29, 240842), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 11, 33, 29, 240000), 'JupyterHub', 'users', '664', 'Server vladimirgorovoy is ready'),
#  (193118, datetime.datetime(2022, 9, 23, 11, 33, 29, 239273), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 11, 33, 29, 239000), 'JupyterHub', 'proxy', '257', 'Adding user vladimirgorovoy to proxy /user/vladimirgorovoy/ => http://10.112.129.80:8888'),
#  (193117, datetime.datetime(2022, 9, 23, 11, 33, 29, 239210), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 11, 33, 29, 238000), 'JupyterHub', 'base', '904', 'User vladimirgorovoy took 23.973 seconds to start'),
#  (193106, datetime.datetime(2022, 9, 23, 11, 33, 24, 842420), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 11, 33, 24, 842000), 'JupyterHub', 'log', '181', '200 POST /hub/api/users/vladimirgorovoy/activity (vladimirgorovoy@10.112.129.80) 20.18ms'),
#  (193116, datetime.datetime(2022, 9, 23, 11, 33, 5, 363858), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 11, 33, 5, 363000), 'JupyterHub', 'log', '181', '200 GET /hub/spawn-pending/vladimirgorovoy (vladimirgorovoy@10.129.0.5) 3.32ms'),
#  (193115, datetime.datetime(2022, 9, 23, 11, 33, 5, 362877), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 11, 33, 5, 362000), 'JupyterHub', 'pages', '402', 'vladimirgorovoy is pending spawn'),
#  (193114, datetime.datetime(2022, 9, 23, 11, 33, 5, 323404), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 11, 33, 5, 323000), 'JupyterHub', 'spawner', '1840', 'Attempting to create pod jupyter-vladimirgorovoy, with timeout 3'),
#  (193113, datetime.datetime(2022, 9, 23, 11, 33, 5, 320887), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 11, 33, 5, 320000), 'JupyterHub', 'spawner', '1887', 'PVC claim-vladimirgorovoy already exists, so did not create new pvc.'),
#  (193112, datetime.datetime(2022, 9, 23, 11, 33, 5, 302458), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 11, 33, 5, 302000), 'JupyterHub', 'log', '181', '302 POST /hub/spawn -> /hub/spawn-pending/vladimirgorovoy (vladimirgorovoy@10.129.0.5) 38.26ms'),
#  (193111, datetime.datetime(2022, 9, 23, 11, 33, 5, 301139), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 11, 33, 5, 300000), 'JupyterHub', 'spawner', '1875', 'Attempting to create pvc claim-vladimirgorovoy, with timeout 3'),
#  (193109, datetime.datetime(2022, 9, 23, 11, 33, 2, 930884), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 11, 33, 2, 930000), 'JupyterHub', 'log', '181', '200 GET /hub/spawn (vladimirgorovoy@10.129.0.5) 5.65ms'),
#  (193108, datetime.datetime(2022, 9, 23, 11, 33, 2, 798064), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 11, 33, 2, 797000), 'JupyterHub', 'log', '181', '302 GET /hub/ -> /hub/spawn (vladimirgorovoy@10.129.0.5) 13.51ms'),
#  (193226, datetime.datetime(2022, 9, 23, 11, 21, 43, 806616), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 11, 21, 43, 806000), 'JupyterHub', 'log', '181', '200 POST /hub/api/users/vladimirgorovoy/activity (vladimirgorovoy@10.112.134.138) 14.34ms'),
#  (193202, datetime.datetime(2022, 9, 23, 11, 16, 45, 492396), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 11, 16, 45, 492000), 'JupyterHub', 'log', '181', '200 POST /hub/api/users/vladimirgorovoy/activity (vladimirgorovoy@10.112.134.138) 11.85ms'),
#  (193184, datetime.datetime(2022, 9, 23, 11, 12, 12, 67366), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 11, 12, 12, 67000), 'JupyterHub', 'log', '181', '200 POST /hub/api/users/vladimirgorovoy/activity (vladimirgorovoy@10.112.134.138) 12.34ms'),
#  (193240, datetime.datetime(2022, 9, 23, 11, 6, 58, 29973), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 11, 6, 58, 29000), 'JupyterHub', 'log', '181', '200 POST /hub/api/users/vladimirgorovoy/activity (vladimirgorovoy@10.112.134.138) 14.35ms'),
#  (192966, datetime.datetime(2022, 9, 23, 11, 2, 3, 587500), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 11, 2, 3, 587000), 'JupyterHub', 'log', '181', '200 POST /hub/api/users/vladimirgorovoy/activity (vladimirgorovoy@10.112.134.138) 14.20ms'),
#  (192934, datetime.datetime(2022, 9, 23, 10, 57, 25, 346537), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 10, 57, 25, 346000), 'JupyterHub', 'log', '181', '200 POST /hub/api/users/vladimirgorovoy/activity (vladimirgorovoy@10.112.134.138) 10.95ms'),
#  (193042, datetime.datetime(2022, 9, 23, 10, 47, 10, 196607), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 10, 47, 10, 196000), 'JupyterHub', 'log', '181', '200 POST /hub/api/users/vladimirgorovoy/activity (vladimirgorovoy@10.112.134.138) 10.75ms'),
#  (193079, datetime.datetime(2022, 9, 23, 10, 42, 9, 321657), 'hub', 'cl1flrrk4hvdbm084md4-akec', 'hub-5bb9b9c56c-5k7nq', 'I', datetime.datetime(2022, 9, 23, 10, 42, 9, 321000), 'JupyterHub', 'log', '181', '200 POST /hub/api/users/vladimirgorovoy/activity (vladimirgorovoy@10.112.134.138) 27.68ms')]

# %% [markdown]
# ### Tasks to play with
# 1. Find your logged activity
# 2. (Hard task) Try to find top 5 logins by activity for the last month. You can measure activity by counting the number of logged records in JupyterHub logs
